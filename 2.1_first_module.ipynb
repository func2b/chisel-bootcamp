// %% [markdown]
// <a name="top"></a><img src="images/chisel_1024.png" alt="Chisel logo" style="width:480px;" />

// %% [markdown]
// # Module 2.1: Your First Chisel Module
// **Prev: [Introduction to Scala](1_intro_to_scala.ipynb)**<br>
// **Next: [Combinational Logic](2.2_comb_logic.ipynb)**
//
// ## Motivation
// Now that you are familiar with Scala, let's start carving out some hardware! Chisel stands for **C**onstructing **H**ardware **I**n a **S**cala **E**mbedded **L**anguage. That means it is a DSL in Scala, allowing you to take advantage of both Scala and Chisel programming within the same code. It is important to understand which code is "Scala" and which code is "Chisel", but we will discuss that more later. For now, think of Chisel and the code in Module 2 as a better way to write Verilog. This module throws an entire Chisel `Module` and tester at you. Just get the gist of it for now. You'll see plenty more examples later.

// %% [markdown]
// ## Setup
// The following cell downloads the dependencies needed for Chisel. You will see it in all future notebooks. **Run this cell now**.

// %%
val path = System.getProperty("user.dir") + "/source/load-ivy.sc"
interp.load.module(ammonite.ops.Path(java.nio.file.FileSystems.getDefault().getPath(path)))
// Out:
// Compiling Main.sc
// Downloading https://repo1.maven.org/maven2/edu/berkeley/cs/chisel3_2.11/3.1.0/chisel3_2.11-3.1.0.pom
// Downloading https://repo1.maven.org/maven2/edu/berkeley/cs/chisel3_2.11/3.1.0/chisel3_2.11-3.1.0.pom.sha1
// Downloaded https://repo1.maven.org/maven2/edu/berkeley/cs/chisel3_2.11/3.1.0/chisel3_2.11-3.1.0.pom.sha1
// Downloaded https://repo1.maven.org/maven2/edu/berkeley/cs/chisel3_2.11/3.1.0/chisel3_2.11-3.1.0.pom
// Downloading https://repo1.maven.org/maven2/edu/berkeley/cs/chisel3_2.11/3.1.0/
// Downloaded https://repo1.maven.org/maven2/edu/berkeley/cs/chisel3_2.11/3.1.0/
// Downloading https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.11.12/scala-library-2.11.12.pom
// Downloading https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.11.12/scala-library-2.11.12.pom.sha1
// Downloading https://repo1.maven.org/maven2/edu/berkeley/cs/firrtl_2.11/1.1.0/firrtl_2.11-1.1.0.pom.sha1
// Downloading https://repo1.maven.org/maven2/edu/berkeley/cs/firrtl_2.11/1.1.0/firrtl_2.11-1.1.0.pom
// Downloading https://repo1.maven.org/maven2/org/scala-lang/scala-reflect/2.11.12/scala-reflect-2.11.12.pom
// Downloading https://repo1.maven.org/maven2/org/scala-lang/scala-reflect/2.11.12/scala-reflect-2.11.12.pom.sha1
// Downloaded https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.11.12/scala-library-2.11.12.pom.sha1
// Downloaded https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.11.12/scala-library-2.11.12.pom
// Downloading https://repo1.maven.org/maven2/com/github/scopt/scopt_2.11/3.6.0/scopt_2.11-3.6.0.pom
// Downloading https://repo1.maven.org/maven2/com/github/scopt/scopt_2.11/3.6.0/scopt_2.11-3.6.0.pom.sha1
// Downloaded https://repo1.maven.org/maven2/com/github/scopt/scopt_2.11/3.6.0/scopt_2.11-3.6.0.pom
// Downloading https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.11.12/
// Downloaded https://repo1.maven.org/maven2/com/github/scopt/scopt_2.11/3.6.0/scopt_2.11-3.6.0.pom.sha1
// Downloading https://repo1.maven.org/maven2/com/github/scopt/scopt_2.11/3.6.0/
// Downloaded https://repo1.maven.org/maven2/edu/berkeley/cs/firrtl_2.11/1.1.0/firrtl_2.11-1.1.0.pom.sha1
// Downloaded https://repo1.maven.org/maven2/edu/berkeley/cs/firrtl_2.11/1.1.0/firrtl_2.11-1.1.0.pom
// Downloading https://repo1.maven.org/maven2/edu/berkeley/cs/firrtl_2.11/1.1.0/
// Downloaded https://repo1.maven.org/maven2/org/scala-lang/scala-reflect/2.11.12/scala-reflect-2.11.12.pom
// Downloaded https://repo1.maven.org/maven2/org/scala-lang/scala-reflect/2.11.12/scala-reflect-2.11.12.pom.sha1
// Downloading https://repo1.maven.org/maven2/org/scala-lang/scala-reflect/2.11.12/
// Downloaded https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.11.12/
// Downloaded https://repo1.maven.org/maven2/com/github/scopt/scopt_2.11/3.6.0/
// Downloaded https://repo1.maven.org/maven2/org/scala-lang/scala-reflect/2.11.12/
// Downloaded https://repo1.maven.org/maven2/edu/berkeley/cs/firrtl_2.11/1.1.0/
// Downloading https://repo1.maven.org/maven2/org/antlr/antlr4-runtime/4.7/antlr4-runtime-4.7.pom
// Downloading https://repo1.maven.org/maven2/org/json4s/json4s-native_2.11/3.5.3/json4s-native_2.11-3.5.3.pom.sha1
// Downloading https://repo1.maven.org/maven2/org/json4s/json4s-native_2.11/3.5.3/json4s-native_2.11-3.5.3.pom
// Downloading https://repo1.maven.org/maven2/com/typesafe/scala-logging/scala-logging_2.11/3.7.2/scala-logging_2.11-3.7.2.pom.sha1
// Downloading https://repo1.maven.org/maven2/com/typesafe/scala-logging/scala-logging_2.11/3.7.2/scala-logging_2.11-3.7.2.pom
// Downloading https://repo1.maven.org/maven2/org/antlr/antlr4-runtime/4.7/antlr4-runtime-4.7.pom.sha1
// Downloaded https://repo1.maven.org/maven2/org/json4s/json4s-native_2.11/3.5.3/json4s-native_2.11-3.5.3.pom.sha1
// Downloaded https://repo1.maven.org/maven2/org/json4s/json4s-native_2.11/3.5.3/json4s-native_2.11-3.5.3.pom
// Downloaded https://repo1.maven.org/maven2/com/typesafe/scala-logging/scala-logging_2.11/3.7.2/scala-logging_2.11-3.7.2.pom
// Downloaded https://repo1.maven.org/maven2/org/antlr/antlr4-runtime/4.7/antlr4-runtime-4.7.pom
// Downloading https://repo1.maven.org/maven2/org/antlr/antlr4/4.7/antlr4-4.7.pom.sha1
// Downloading https://repo1.maven.org/maven2/org/antlr/antlr4/4.7/antlr4-4.7.pom
// Downloading https://repo1.maven.org/maven2/ch/qos/logback/logback-classic/1.2.3/logback-classic-1.2.3.pom.sha1
// Downloaded https://repo1.maven.org/maven2/com/typesafe/scala-logging/scala-logging_2.11/3.7.2/scala-logging_2.11-3.7.2.pom.sha1
// Downloading https://repo1.maven.org/maven2/ch/qos/logback/logback-classic/1.2.3/logback-classic-1.2.3.pom
// Downloading https://repo1.maven.org/maven2/net/jcazevedo/moultingyaml_2.11/0.4.0/moultingyaml_2.11-0.4.0.pom
// Downloaded https://repo1.maven.org/maven2/ch/qos/logback/logback-classic/1.2.3/logback-classic-1.2.3.pom.sha1
// Downloading https://repo1.maven.org/maven2/net/jcazevedo/moultingyaml_2.11/0.4.0/moultingyaml_2.11-0.4.0.pom.sha1
// Downloaded https://repo1.maven.org/maven2/org/antlr/antlr4/4.7/antlr4-4.7.pom.sha1
// Downloading https://repo1.maven.org/maven2/org/json4s/json4s-native_2.11/3.5.3/
// Downloaded https://repo1.maven.org/maven2/org/antlr/antlr4/4.7/antlr4-4.7.pom
// Downloaded https://repo1.maven.org/maven2/net/jcazevedo/moultingyaml_2.11/0.4.0/moultingyaml_2.11-0.4.0.pom
// Downloading https://repo1.maven.org/maven2/com/typesafe/scala-logging/scala-logging_2.11/3.7.2/
// Downloading https://repo1.maven.org/maven2/org/antlr/antlr4/4.7/
// Downloaded https://repo1.maven.org/maven2/org/antlr/antlr4-runtime/4.7/antlr4-runtime-4.7.pom.sha1
// Downloading https://repo1.maven.org/maven2/org/antlr/antlr4-runtime/4.7/
// Downloaded https://repo1.maven.org/maven2/ch/qos/logback/logback-classic/1.2.3/logback-classic-1.2.3.pom
// Downloading https://repo1.maven.org/maven2/ch/qos/logback/logback-classic/1.2.3/
// Downloaded https://repo1.maven.org/maven2/net/jcazevedo/moultingyaml_2.11/0.4.0/moultingyaml_2.11-0.4.0.pom.sha1
// Downloading https://repo1.maven.org/maven2/net/jcazevedo/moultingyaml_2.11/0.4.0/
// Downloaded https://repo1.maven.org/maven2/org/json4s/json4s-native_2.11/3.5.3/
// Downloaded https://repo1.maven.org/maven2/com/typesafe/scala-logging/scala-logging_2.11/3.7.2/
// Downloaded https://repo1.maven.org/maven2/org/antlr/antlr4/4.7/
// Downloaded https://repo1.maven.org/maven2/org/antlr/antlr4-runtime/4.7/
// Downloaded https://repo1.maven.org/maven2/ch/qos/logback/logback-classic/1.2.3/
// Downloaded https://repo1.maven.org/maven2/net/jcazevedo/moultingyaml_2.11/0.4.0/
// Downloading https://repo1.maven.org/maven2/ch/qos/logback/logback-parent/1.2.3/logback-parent-1.2.3.pom
// Downloading https://repo1.maven.org/maven2/org/antlr/antlr4-master/4.7/antlr4-master-4.7.pom
// Downloading https://repo1.maven.org/maven2/ch/qos/logback/logback-parent/1.2.3/logback-parent-1.2.3.pom.sha1
// Downloading https://repo1.maven.org/maven2/org/antlr/antlr4-master/4.7/antlr4-master-4.7.pom.sha1
// Downloaded https://repo1.maven.org/maven2/ch/qos/logback/logback-parent/1.2.3/logback-parent-1.2.3.pom.sha1
// Downloaded https://repo1.maven.org/maven2/org/antlr/antlr4-master/4.7/antlr4-master-4.7.pom
// Downloaded https://repo1.maven.org/maven2/org/antlr/antlr4-master/4.7/antlr4-master-4.7.pom.sha1
// Downloading https://repo1.maven.org/maven2/org/antlr/antlr4-master/4.7/
// Downloaded https://repo1.maven.org/maven2/ch/qos/logback/logback-parent/1.2.3/logback-parent-1.2.3.pom
// Downloading https://repo1.maven.org/maven2/ch/qos/logback/logback-parent/1.2.3/
// Downloaded https://repo1.maven.org/maven2/org/antlr/antlr4-master/4.7/
// Downloaded https://repo1.maven.org/maven2/ch/qos/logback/logback-parent/1.2.3/
// Downloading https://repo1.maven.org/maven2/org/sonatype/oss/oss-parent/9/oss-parent-9.pom
// Downloading https://repo1.maven.org/maven2/org/sonatype/oss/oss-parent/9/oss-parent-9.pom.sha1
// Downloaded https://repo1.maven.org/maven2/org/sonatype/oss/oss-parent/9/oss-parent-9.pom.sha1
// Downloaded https://repo1.maven.org/maven2/org/sonatype/oss/oss-parent/9/oss-parent-9.pom
// Downloading https://repo1.maven.org/maven2/org/sonatype/oss/oss-parent/9/
// Downloaded https://repo1.maven.org/maven2/org/sonatype/oss/oss-parent/9/
// Downloading https://repo1.maven.org/maven2/org/yaml/snakeyaml/1.17/snakeyaml-1.17.pom
// Downloading https://repo1.maven.org/maven2/com/github/nscala-time/nscala-time_2.11/2.14.0/nscala-time_2.11-2.14.0.pom.sha1
// Downloading https://repo1.maven.org/maven2/org/slf4j/slf4j-api/1.7.25/slf4j-api-1.7.25.pom.sha1
// Downloading https://repo1.maven.org/maven2/org/slf4j/slf4j-api/1.7.25/slf4j-api-1.7.25.pom
// Downloading https://repo1.maven.org/maven2/org/yaml/snakeyaml/1.17/snakeyaml-1.17.pom.sha1
// Downloading https://repo1.maven.org/maven2/com/github/nscala-time/nscala-time_2.11/2.14.0/nscala-time_2.11-2.14.0.pom
// Downloaded https://repo1.maven.org/maven2/org/yaml/snakeyaml/1.17/snakeyaml-1.17.pom.sha1
// Downloaded https://repo1.maven.org/maven2/com/github/nscala-time/nscala-time_2.11/2.14.0/nscala-time_2.11-2.14.0.pom.sha1
// Downloaded https://repo1.maven.org/maven2/org/slf4j/slf4j-api/1.7.25/slf4j-api-1.7.25.pom
// Downloading https://repo1.maven.org/maven2/org/antlr/antlr-runtime/3.5.2/antlr-runtime-3.5.2.pom
// Downloading https://repo1.maven.org/maven2/org/glassfish/javax.json/1.0.4/javax.json-1.0.4.pom
// Downloading https://repo1.maven.org/maven2/org/antlr/antlr-runtime/3.5.2/antlr-runtime-3.5.2.pom.sha1
// Downloaded https://repo1.maven.org/maven2/org/slf4j/slf4j-api/1.7.25/slf4j-api-1.7.25.pom.sha1
// Downloading https://repo1.maven.org/maven2/org/glassfish/javax.json/1.0.4/javax.json-1.0.4.pom.sha1
// Downloaded https://repo1.maven.org/maven2/org/yaml/snakeyaml/1.17/snakeyaml-1.17.pom
// Downloading https://repo1.maven.org/maven2/org/json4s/json4s-core_2.11/3.5.3/json4s-core_2.11-3.5.3.pom
// Downloaded https://repo1.maven.org/maven2/org/antlr/antlr-runtime/3.5.2/antlr-runtime-3.5.2.pom
// Downloading https://repo1.maven.org/maven2/org/json4s/json4s-core_2.11/3.5.3/json4s-core_2.11-3.5.3.pom.sha1
// Downloaded https://repo1.maven.org/maven2/org/glassfish/javax.json/1.0.4/javax.json-1.0.4.pom.sha1
// Downloaded https://repo1.maven.org/maven2/org/antlr/antlr-runtime/3.5.2/antlr-runtime-3.5.2.pom.sha1
// Downloading https://repo1.maven.org/maven2/ch/qos/logback/logback-core/1.2.3/logback-core-1.2.3.pom
// Downloading https://repo1.maven.org/maven2/ch/qos/logback/logback-core/1.2.3/logback-core-1.2.3.pom.sha1
// Downloaded https://repo1.maven.org/maven2/org/glassfish/javax.json/1.0.4/javax.json-1.0.4.pom
// Downloading https://repo1.maven.org/maven2/org/abego/treelayout/org.abego.treelayout.core/1.0.3/org.abego.treelayout.core-1.0.3.pom
// Downloaded https://repo1.maven.org/maven2/com/github/nscala-time/nscala-time_2.11/2.14.0/nscala-time_2.11-2.14.0.pom
// Downloading https://repo1.maven.org/maven2/org/abego/treelayout/org.abego.treelayout.core/1.0.3/org.abego.treelayout.core-1.0.3.pom.sha1
// Downloaded https://repo1.maven.org/maven2/org/json4s/json4s-core_2.11/3.5.3/json4s-core_2.11-3.5.3.pom.sha1
// Downloading https://repo1.maven.org/maven2/com/ibm/icu/icu4j/58.2/icu4j-58.2.pom
// Downloaded https://repo1.maven.org/maven2/ch/qos/logback/logback-core/1.2.3/logback-core-1.2.3.pom
// Downloading https://repo1.maven.org/maven2/com/ibm/icu/icu4j/58.2/icu4j-58.2.pom.sha1
// Downloaded https://repo1.maven.org/maven2/org/abego/treelayout/org.abego.treelayout.core/1.0.3/org.abego.treelayout.core-1.0.3.pom
// Downloading https://repo1.maven.org/maven2/org/antlr/ST4/4.0.8/ST4-4.0.8.pom
// Downloaded https://repo1.maven.org/maven2/org/abego/treelayout/org.abego.treelayout.core/1.0.3/org.abego.treelayout.core-1.0.3.pom.sha1
// Downloading https://repo1.maven.org/maven2/org/antlr/ST4/4.0.8/ST4-4.0.8.pom.sha1
// Downloaded https://repo1.maven.org/maven2/com/ibm/icu/icu4j/58.2/icu4j-58.2.pom
// Downloaded https://repo1.maven.org/maven2/com/ibm/icu/icu4j/58.2/icu4j-58.2.pom.sha1
// Downloading https://repo1.maven.org/maven2/org/slf4j/slf4j-api/1.7.25/
// Downloading https://repo1.maven.org/maven2/org/yaml/snakeyaml/1.17/
// Downloaded https://repo1.maven.org/maven2/org/antlr/ST4/4.0.8/ST4-4.0.8.pom.sha1
// Downloading https://repo1.maven.org/maven2/org/antlr/antlr-runtime/3.5.2/
// Downloaded https://repo1.maven.org/maven2/ch/qos/logback/logback-core/1.2.3/logback-core-1.2.3.pom.sha1
// Downloaded https://repo1.maven.org/maven2/org/slf4j/slf4j-api/1.7.25/
// Downloading https://repo1.maven.org/maven2/org/glassfish/javax.json/1.0.4/
// Downloading https://repo1.maven.org/maven2/com/github/nscala-time/nscala-time_2.11/2.14.0/
// Downloaded https://repo1.maven.org/maven2/org/yaml/snakeyaml/1.17/
// Downloading https://repo1.maven.org/maven2/org/abego/treelayout/org.abego.treelayout.core/1.0.3/
// Downloaded https://repo1.maven.org/maven2/org/antlr/ST4/4.0.8/ST4-4.0.8.pom
// Downloading https://repo1.maven.org/maven2/com/ibm/icu/icu4j/58.2/
// Downloaded https://repo1.maven.org/maven2/org/antlr/antlr-runtime/3.5.2/
// Downloading https://repo1.maven.org/maven2/ch/qos/logback/logback-core/1.2.3/
// Downloaded https://repo1.maven.org/maven2/com/github/nscala-time/nscala-time_2.11/2.14.0/
// Downloaded https://repo1.maven.org/maven2/org/glassfish/javax.json/1.0.4/
// Downloading https://repo1.maven.org/maven2/org/antlr/ST4/4.0.8/
// Downloaded https://repo1.maven.org/maven2/org/abego/treelayout/org.abego.treelayout.core/1.0.3/
// Downloaded https://repo1.maven.org/maven2/com/ibm/icu/icu4j/58.2/
// https://repo1.maven.org/maven2/org/json4s/json4s-core_2.11/3.5.3/json4s-core_…
//
// Downloaded https://repo1.maven.org/maven2/org/json4s/json4s-core_2.11/3.5.3/json4s-core_2.11-3.5.3.pom
// Downloading https://repo1.maven.org/maven2/org/json4s/json4s-core_2.11/3.5.3/
// Downloaded https://repo1.maven.org/maven2/org/antlr/ST4/4.0.8/
// Downloaded https://repo1.maven.org/maven2/org/json4s/json4s-core_2.11/3.5.3/
// Downloaded https://repo1.maven.org/maven2/ch/qos/logback/logback-core/1.2.3/
// Downloading https://repo1.maven.org/maven2/org/glassfish/json/1.0.4/json-1.0.4.pom
// Downloading https://repo1.maven.org/maven2/org/sonatype/oss/oss-parent/7/oss-parent-7.pom.sha1
// Downloading https://repo1.maven.org/maven2/org/sonatype/oss/oss-parent/7/oss-parent-7.pom
// Downloading https://repo1.maven.org/maven2/org/antlr/antlr-master/3.5.2/antlr-master-3.5.2.pom
// Downloading https://repo1.maven.org/maven2/org/antlr/antlr-master/3.5.2/antlr-master-3.5.2.pom.sha1
// Downloading https://repo1.maven.org/maven2/org/glassfish/json/1.0.4/json-1.0.4.pom.sha1
// Downloaded https://repo1.maven.org/maven2/org/sonatype/oss/oss-parent/7/oss-parent-7.pom
// Downloading https://repo1.maven.org/maven2/org/slf4j/slf4j-parent/1.7.25/slf4j-parent-1.7.25.pom
// Downloaded https://repo1.maven.org/maven2/org/sonatype/oss/oss-parent/7/oss-parent-7.pom.sha1
// Downloaded https://repo1.maven.org/maven2/org/antlr/antlr-master/3.5.2/antlr-master-3.5.2.pom.sha1
// Downloading https://repo1.maven.org/maven2/org/slf4j/slf4j-parent/1.7.25/slf4j-parent-1.7.25.pom.sha1
// Downloading https://repo1.maven.org/maven2/org/sonatype/oss/oss-parent/7/
// Downloaded https://repo1.maven.org/maven2/org/antlr/antlr-master/3.5.2/antlr-master-3.5.2.pom
// Downloading https://repo1.maven.org/maven2/org/antlr/antlr-master/3.5.2/
// Downloaded https://repo1.maven.org/maven2/org/glassfish/json/1.0.4/json-1.0.4.pom
// Downloaded https://repo1.maven.org/maven2/org/sonatype/oss/oss-parent/7/
// Downloaded https://repo1.maven.org/maven2/org/slf4j/slf4j-parent/1.7.25/slf4j-parent-1.7.25.pom.sha1
// Downloaded https://repo1.maven.org/maven2/org/antlr/antlr-master/3.5.2/
// Downloaded https://repo1.maven.org/maven2/org/slf4j/slf4j-parent/1.7.25/slf4j-parent-1.7.25.pom
// Downloading https://repo1.maven.org/maven2/org/slf4j/slf4j-parent/1.7.25/
// Downloaded https://repo1.maven.org/maven2/org/glassfish/json/1.0.4/json-1.0.4.pom.sha1
// Downloading https://repo1.maven.org/maven2/org/glassfish/json/1.0.4/
// Downloaded https://repo1.maven.org/maven2/org/slf4j/slf4j-parent/1.7.25/
// Downloaded https://repo1.maven.org/maven2/org/glassfish/json/1.0.4/
// Downloading https://repo1.maven.org/maven2/net/java/jvnet-parent/3/jvnet-parent-3.pom
// Downloading https://repo1.maven.org/maven2/net/java/jvnet-parent/3/jvnet-parent-3.pom.sha1
// Downloaded https://repo1.maven.org/maven2/net/java/jvnet-parent/3/jvnet-parent-3.pom.sha1
// Downloaded https://repo1.maven.org/maven2/net/java/jvnet-parent/3/jvnet-parent-3.pom
// Downloading https://repo1.maven.org/maven2/net/java/jvnet-parent/3/
// Downloaded https://repo1.maven.org/maven2/net/java/jvnet-parent/3/
// Downloading https://repo1.maven.org/maven2/joda-time/joda-time/2.9.4/joda-time-2.9.4.pom
// Downloading https://repo1.maven.org/maven2/org/joda/joda-convert/1.2/joda-convert-1.2.pom
// Downloading https://repo1.maven.org/maven2/com/thoughtworks/paranamer/paranamer/2.8/paranamer-2.8.pom.sha1
// Downloading https://repo1.maven.org/maven2/com/thoughtworks/paranamer/paranamer/2.8/paranamer-2.8.pom
// Downloading https://repo1.maven.org/maven2/joda-time/joda-time/2.9.4/joda-time-2.9.4.pom.sha1
// Downloading https://repo1.maven.org/maven2/org/joda/joda-convert/1.2/joda-convert-1.2.pom.sha1
// Downloaded https://repo1.maven.org/maven2/com/thoughtworks/paranamer/paranamer/2.8/paranamer-2.8.pom.sha1
// Downloading https://repo1.maven.org/maven2/org/json4s/json4s-scalap_2.11/3.5.3/json4s-scalap_2.11-3.5.3.pom
// Downloaded https://repo1.maven.org/maven2/joda-time/joda-time/2.9.4/joda-time-2.9.4.pom.sha1
// Downloading https://repo1.maven.org/maven2/org/json4s/json4s-scalap_2.11/3.5.3/json4s-scalap_2.11-3.5.3.pom.sha1
// Downloaded https://repo1.maven.org/maven2/org/joda/joda-convert/1.2/joda-convert-1.2.pom
// Downloaded https://repo1.maven.org/maven2/com/thoughtworks/paranamer/paranamer/2.8/paranamer-2.8.pom
// Downloading https://repo1.maven.org/maven2/org/json4s/json4s-ast_2.11/3.5.3/json4s-ast_2.11-3.5.3.pom
// Downloading https://repo1.maven.org/maven2/org/json4s/json4s-ast_2.11/3.5.3/json4s-ast_2.11-3.5.3.pom.sha1
// Downloaded https://repo1.maven.org/maven2/org/json4s/json4s-scalap_2.11/3.5.3/json4s-scalap_2.11-3.5.3.pom.sha1
// Downloaded https://repo1.maven.org/maven2/org/json4s/json4s-scalap_2.11/3.5.3/json4s-scalap_2.11-3.5.3.pom
// Downloading https://repo1.maven.org/maven2/com/thoughtworks/paranamer/paranamer/2.8/
// Downloading https://repo1.maven.org/maven2/org/json4s/json4s-scalap_2.11/3.5.3/
// Downloaded https://repo1.maven.org/maven2/org/json4s/json4s-ast_2.11/3.5.3/json4s-ast_2.11-3.5.3.pom.sha1
// Downloaded https://repo1.maven.org/maven2/org/json4s/json4s-ast_2.11/3.5.3/json4s-ast_2.11-3.5.3.pom
// Downloading https://repo1.maven.org/maven2/org/json4s/json4s-ast_2.11/3.5.3/
// Downloaded https://repo1.maven.org/maven2/joda-time/joda-time/2.9.4/joda-time-2.9.4.pom
// Downloading https://repo1.maven.org/maven2/joda-time/joda-time/2.9.4/
// Downloaded https://repo1.maven.org/maven2/org/joda/joda-convert/1.2/joda-convert-1.2.pom.sha1
// Downloading https://repo1.maven.org/maven2/org/joda/joda-convert/1.2/
// Downloaded https://repo1.maven.org/maven2/com/thoughtworks/paranamer/paranamer/2.8/
// Downloaded https://repo1.maven.org/maven2/org/json4s/json4s-scalap_2.11/3.5.3/
// Downloaded https://repo1.maven.org/maven2/org/json4s/json4s-ast_2.11/3.5.3/
// Downloaded https://repo1.maven.org/maven2/joda-time/joda-time/2.9.4/
// Downloaded https://repo1.maven.org/maven2/org/joda/joda-convert/1.2/
// Downloading https://repo1.maven.org/maven2/com/thoughtworks/paranamer/paranamer-parent/2.8/paranamer-parent-2.8.pom
// Downloading https://repo1.maven.org/maven2/com/thoughtworks/paranamer/paranamer-parent/2.8/paranamer-parent-2.8.pom.sha1
// Downloaded https://repo1.maven.org/maven2/com/thoughtworks/paranamer/paranamer-parent/2.8/paranamer-parent-2.8.pom.sha1
// Downloaded https://repo1.maven.org/maven2/com/thoughtworks/paranamer/paranamer-parent/2.8/paranamer-parent-2.8.pom
// Downloading https://repo1.maven.org/maven2/com/thoughtworks/paranamer/paranamer-parent/2.8/
// Downloaded https://repo1.maven.org/maven2/com/thoughtworks/paranamer/paranamer-parent/2.8/
// Downloading https://repo1.maven.org/maven2/org/antlr/antlr4/4.7/antlr4-4.7.jar
// Downloading https://repo1.maven.org/maven2/org/json4s/json4s-scalap_2.11/3.5.3/json4s-scalap_2.11-3.5.3.jar
// Downloading https://repo1.maven.org/maven2/org/json4s/json4s-scalap_2.11/3.5.3/json4s-scalap_2.11-3.5.3.jar.sha1
// Downloading https://repo1.maven.org/maven2/org/joda/joda-convert/1.2/joda-convert-1.2.jar
// Downloading https://repo1.maven.org/maven2/org/joda/joda-convert/1.2/joda-convert-1.2.jar.sha1
// Downloading https://repo1.maven.org/maven2/org/json4s/json4s-native_2.11/3.5.3/json4s-native_2.11-3.5.3.jar
// Downloaded https://repo1.maven.org/maven2/org/json4s/json4s-scalap_2.11/3.5.3/json4s-scalap_2.11-3.5.3.jar.sha1
// Downloading https://repo1.maven.org/maven2/org/json4s/json4s-native_2.11/3.5.3/json4s-native_2.11-3.5.3.jar.sha1
// Downloaded https://repo1.maven.org/maven2/org/joda/joda-convert/1.2/joda-convert-1.2.jar.sha1
// Downloading https://repo1.maven.org/maven2/org/abego/treelayout/org.abego.treelayout.core/1.0.3/org.abego.treelayout.core-1.0.3.jar
// Downloaded https://repo1.maven.org/maven2/org/json4s/json4s-native_2.11/3.5.3/json4s-native_2.11-3.5.3.jar.sha1
// Downloading https://repo1.maven.org/maven2/org/abego/treelayout/org.abego.treelayout.core/1.0.3/org.abego.treelayout.core-1.0.3.jar.sha1
// Downloaded https://repo1.maven.org/maven2/org/abego/treelayout/org.abego.treelayout.core/1.0.3/org.abego.treelayout.core-1.0.3.jar.sha1
// Downloading https://repo1.maven.org/maven2/org/antlr/antlr4/4.7/antlr4-4.7.jar.sha1
// Downloaded https://repo1.maven.org/maven2/org/antlr/antlr4/4.7/antlr4-4.7.jar.sha1
// Downloading https://repo1.maven.org/maven2/org/yaml/snakeyaml/1.17/snakeyaml-1.17.jar.sha1
// Downloaded https://repo1.maven.org/maven2/org/joda/joda-convert/1.2/joda-convert-1.2.jar
// Downloading https://repo1.maven.org/maven2/edu/berkeley/cs/firrtl_2.11/1.1.0/firrtl_2.11-1.1.0.jar.sha1
// Downloaded https://repo1.maven.org/maven2/org/abego/treelayout/org.abego.treelayout.core/1.0.3/org.abego.treelayout.core-1.0.3.jar
// Downloading https://repo1.maven.org/maven2/edu/berkeley/cs/firrtl_2.11/1.1.0/firrtl_2.11-1.1.0.jar
// Downloaded https://repo1.maven.org/maven2/org/yaml/snakeyaml/1.17/snakeyaml-1.17.jar.sha1
// Downloading https://repo1.maven.org/maven2/org/yaml/snakeyaml/1.17/snakeyaml-1.17.jar
// Downloaded https://repo1.maven.org/maven2/edu/berkeley/cs/firrtl_2.11/1.1.0/firrtl_2.11-1.1.0.jar.sha1
// Downloading https://repo1.maven.org/maven2/org/antlr/antlr4-runtime/4.7/antlr4-runtime-4.7.jar.sha1
// Downloaded https://repo1.maven.org/maven2/org/json4s/json4s-native_2.11/3.5.3/json4s-native_2.11-3.5.3.jar
// Downloading https://repo1.maven.org/maven2/org/slf4j/slf4j-api/1.7.25/slf4j-api-1.7.25.jar
// Downloaded https://repo1.maven.org/maven2/org/json4s/json4s-scalap_2.11/3.5.3/json4s-scalap_2.11-3.5.3.jar
// Downloading https://repo1.maven.org/maven2/org/slf4j/slf4j-api/1.7.25/slf4j-api-1.7.25.jar.sha1
// Downloaded https://repo1.maven.org/maven2/org/antlr/antlr4-runtime/4.7/antlr4-runtime-4.7.jar.sha1
// Downloading https://repo1.maven.org/maven2/org/antlr/ST4/4.0.8/ST4-4.0.8.jar
// Downloaded https://repo1.maven.org/maven2/org/slf4j/slf4j-api/1.7.25/slf4j-api-1.7.25.jar.sha1
// Downloading https://repo1.maven.org/maven2/org/antlr/ST4/4.0.8/ST4-4.0.8.jar.sha1
// Downloaded https://repo1.maven.org/maven2/org/antlr/ST4/4.0.8/ST4-4.0.8.jar.sha1
// Downloading https://repo1.maven.org/maven2/org/scala-lang/scala-reflect/2.11.12/scala-reflect-2.11.12.jar
// https://repo1.maven.org/maven2/org/antlr/antlr4/4.7/antlr4-4.7… (13.70 %, 16330…
//
// Downloaded https://repo1.maven.org/maven2/org/slf4j/slf4j-api/1.7.25/slf4j-api-1.7.25.jar
// Downloading https://repo1.maven.org/maven2/org/scala-lang/scala-reflect/2.11.12/scala-reflect-2.11.12.jar.sha1
// Downloaded https://repo1.maven.org/maven2/org/scala-lang/scala-reflect/2.11.12/scala-reflect-2.11.12.jar.sha1
// Downloading https://repo1.maven.org/maven2/org/glassfish/javax.json/1.0.4/javax.json-1.0.4.jar.sha1
// Downloaded https://repo1.maven.org/maven2/org/glassfish/javax.json/1.0.4/javax.json-1.0.4.jar.sha1
// Downloading https://repo1.maven.org/maven2/org/glassfish/javax.json/1.0.4/javax.json-1.0.4.jar
// Downloaded https://repo1.maven.org/maven2/org/yaml/snakeyaml/1.17/snakeyaml-1.17.jar
// Downloading https://repo1.maven.org/maven2/org/antlr/antlr4-runtime/4.7/antlr4-runtime-4.7.jar
// https://repo1.maven.org/maven2/org/antlr/ST4/4.0.8/ST4-4.0.8.j… (54.49 %, 13053…
// https://repo1.maven.org/maven2/org/scala-lang/scala-reflect/2.… (26.21 %, 12118…
// https://repo1.maven.org/maven2/org/antlr/antlr4/4.7/antlr4-4.7… (20.57 %, 24522…
// https://repo1.maven.org/maven2/edu/berkeley/cs/firrtl_2.11/1.1… (5.16 %, 163302…
//
// Downloaded https://repo1.maven.org/maven2/org/glassfish/javax.json/1.0.4/javax.json-1.0.4.jar
// Downloading https://repo1.maven.org/maven2/com/ibm/icu/icu4j/58.2/icu4j-58.2.jar
// Downloaded https://repo1.maven.org/maven2/org/antlr/antlr4-runtime/4.7/antlr4-runtime-4.7.jar
// Downloading https://repo1.maven.org/maven2/com/ibm/icu/icu4j/58.2/icu4j-58.2.jar.sha1
// Downloaded https://repo1.maven.org/maven2/com/ibm/icu/icu4j/58.2/icu4j-58.2.jar.sha1
// Downloading https://repo1.maven.org/maven2/ch/qos/logback/logback-core/1.2.3/logback-core-1.2.3.jar
// Downloaded https://repo1.maven.org/maven2/org/antlr/ST4/4.0.8/ST4-4.0.8.jar
// Downloading https://repo1.maven.org/maven2/ch/qos/logback/logback-core/1.2.3/logback-core-1.2.3.jar.sha1
// https://repo1.maven.org/maven2/org/scala-lang/scala-reflect/2.… (59.53 %, 27519…
// https://repo1.maven.org/maven2/org/antlr/antlr4/4.7/antlr4-4.7… (26.07 %, 31075…
// https://repo1.maven.org/maven2/edu/berkeley/cs/firrtl_2.11/1.1… (8.79 %, 277990…
// Downloaded https://repo1.maven.org/maven2/ch/qos/logback/logback-core/1.2.3/logback-core-1.2.3.jar.sha1
// Downloading https://repo1.maven.org/maven2/com/github/nscala-time/nscala-time_2.11/2.14.0/nscala-time_2.11-2.14.0.jar
// Downloaded https://repo1.maven.org/maven2/ch/qos/logback/logback-core/1.2.3/logback-core-1.2.3.jar
// Downloading https://repo1.maven.org/maven2/com/github/nscala-time/nscala-time_2.11/2.14.0/nscala-time_2.11-2.14.0.jar.sha1
// Downloaded https://repo1.maven.org/maven2/com/github/nscala-time/nscala-time_2.11/2.14.0/nscala-time_2.11-2.14.0.jar.sha1
// Downloading https://repo1.maven.org/maven2/org/antlr/antlr-runtime/3.5.2/antlr-runtime-3.5.2.jar
// Downloaded https://repo1.maven.org/maven2/org/antlr/antlr-runtime/3.5.2/antlr-runtime-3.5.2.jar
// Downloading https://repo1.maven.org/maven2/org/antlr/antlr-runtime/3.5.2/antlr-runtime-3.5.2.jar.sha1
// https://repo1.maven.org/maven2/org/scala-lang/scala-reflect/2.… (75.12 %, 34728…
// https://repo1.maven.org/maven2/com/ibm/icu/icu4j/58.2/icu4j-58… (34.96 %, 40796…
// https://repo1.maven.org/maven2/org/antlr/antlr4/4.7/antlr4-4.7… (31.56 %, 37629…
// https://repo1.maven.org/maven2/edu/berkeley/cs/firrtl_2.11/1.1… (13.45 %, 42544…
//
// Downloaded https://repo1.maven.org/maven2/org/antlr/antlr-runtime/3.5.2/antlr-runtime-3.5.2.jar.sha1
// Downloading https://repo1.maven.org/maven2/org/json4s/json4s-ast_2.11/3.5.3/json4s-ast_2.11-3.5.3.jar
// Downloaded https://repo1.maven.org/maven2/org/json4s/json4s-ast_2.11/3.5.3/json4s-ast_2.11-3.5.3.jar
// Downloading https://repo1.maven.org/maven2/org/json4s/json4s-ast_2.11/3.5.3/json4s-ast_2.11-3.5.3.jar.sha1
// Downloaded https://repo1.maven.org/maven2/org/json4s/json4s-ast_2.11/3.5.3/json4s-ast_2.11-3.5.3.jar.sha1
// Downloading https://repo1.maven.org/maven2/com/typesafe/scala-logging/scala-logging_2.11/3.7.2/scala-logging_2.11-3.7.2.jar
// https://repo1.maven.org/maven2/org/scala-lang/scala-reflect/2.… (86.11 %, 39807…
// https://repo1.maven.org/maven2/com/github/nscala-time/nscala-t… (63.67 %, 13053…
// https://repo1.maven.org/maven2/com/ibm/icu/icu4j/58.2/icu4j-58… (49.99 %, 58327…
// https://repo1.maven.org/maven2/org/antlr/antlr4/4.7/antlr4-4.7… (38.43 %, 45821…
// https://repo1.maven.org/maven2/edu/berkeley/cs/firrtl_2.11/1.1… (17.08 %, 54013…
//
// Downloaded https://repo1.maven.org/maven2/com/typesafe/scala-logging/scala-logging_2.11/3.7.2/scala-logging_2.11-3.7.2.jar
// Downloading https://repo1.maven.org/maven2/com/typesafe/scala-logging/scala-logging_2.11/3.7.2/scala-logging_2.11-3.7.2.jar.sha1
// Downloaded https://repo1.maven.org/maven2/com/typesafe/scala-logging/scala-logging_2.11/3.7.2/scala-logging_2.11-3.7.2.jar.sha1
// Downloading https://repo1.maven.org/maven2/net/jcazevedo/moultingyaml_2.11/0.4.0/moultingyaml_2.11-0.4.0.jar
// https://repo1.maven.org/maven2/org/scala-lang/scala-reflect/2.… (93.55 %, 43248…
// https://repo1.maven.org/maven2/com/github/nscala-time/nscala-t… (87.65 %, 17968…
// https://repo1.maven.org/maven2/com/ibm/icu/icu4j/58.2/icu4j-58… (59.40 %, 69304…
// https://repo1.maven.org/maven2/org/antlr/antlr4/4.7/antlr4-4.7… (46.68 %, 55651…
// https://repo1.maven.org/maven2/edu/berkeley/cs/firrtl_2.11/1.1… (20.19 %, 63843…
//
// Downloaded https://repo1.maven.org/maven2/com/github/nscala-time/nscala-time_2.11/2.14.0/nscala-time_2.11-2.14.0.jar
// Downloading https://repo1.maven.org/maven2/net/jcazevedo/moultingyaml_2.11/0.4.0/moultingyaml_2.11-0.4.0.jar.sha1
// Downloaded https://repo1.maven.org/maven2/net/jcazevedo/moultingyaml_2.11/0.4.0/moultingyaml_2.11-0.4.0.jar.sha1
// Downloading https://repo1.maven.org/maven2/org/json4s/json4s-core_2.11/3.5.3/json4s-core_2.11-3.5.3.jar
// Downloaded https://repo1.maven.org/maven2/net/jcazevedo/moultingyaml_2.11/0.4.0/moultingyaml_2.11-0.4.0.jar
// Downloading https://repo1.maven.org/maven2/org/json4s/json4s-core_2.11/3.5.3/json4s-core_2.11-3.5.3.jar.sha1
// Downloaded https://repo1.maven.org/maven2/org/json4s/json4s-core_2.11/3.5.3/json4s-core_2.11-3.5.3.jar.sha1
// Downloading https://repo1.maven.org/maven2/com/github/scopt/scopt_2.11/3.6.0/scopt_2.11-3.6.0.jar
// https://repo1.maven.org/maven2/org/scala-lang/scala-reflect/2.… (97.80 %, 45214…
// https://repo1.maven.org/maven2/com/ibm/icu/icu4j/58.2/icu4j-58… (63.47 %, 74055…
// https://repo1.maven.org/maven2/org/antlr/antlr4/4.7/antlr4-4.7… (53.55 %, 63843…
// https://repo1.maven.org/maven2/edu/berkeley/cs/firrtl_2.11/1.1… (22.78 %, 72035…
//
// Downloaded https://repo1.maven.org/maven2/org/scala-lang/scala-reflect/2.11.12/scala-reflect-2.11.12.jar
// Downloading https://repo1.maven.org/maven2/com/github/scopt/scopt_2.11/3.6.0/scopt_2.11-3.6.0.jar.sha1
// Downloaded https://repo1.maven.org/maven2/com/github/scopt/scopt_2.11/3.6.0/scopt_2.11-3.6.0.jar
// Downloading https://repo1.maven.org/maven2/ch/qos/logback/logback-classic/1.2.3/logback-classic-1.2.3.jar
// Downloaded https://repo1.maven.org/maven2/com/github/scopt/scopt_2.11/3.6.0/scopt_2.11-3.6.0.jar.sha1
// Downloading https://repo1.maven.org/maven2/ch/qos/logback/logback-classic/1.2.3/logback-classic-1.2.3.jar.sha1
// Downloaded https://repo1.maven.org/maven2/ch/qos/logback/logback-classic/1.2.3/logback-classic-1.2.3.jar.sha1
// Downloading https://repo1.maven.org/maven2/edu/berkeley/cs/chisel3_2.11/3.1.0/chisel3_2.11-3.1.0.jar
// https://repo1.maven.org/maven2/com/ibm/icu/icu4j/58.2/icu4j-58… (67.26 %, 78479…
// https://repo1.maven.org/maven2/org/antlr/antlr4/4.7/antlr4-4.7… (61.79 %, 73674…
// https://repo1.maven.org/maven2/edu/berkeley/cs/firrtl_2.11/1.1… (25.89 %, 81866…
// https://repo1.maven.org/maven2/org/json4s/json4s-core_2.11/3.5… (9.42 %, 64998 …
//
// Downloaded https://repo1.maven.org/maven2/ch/qos/logback/logback-classic/1.2.3/logback-classic-1.2.3.jar
// Downloading https://repo1.maven.org/maven2/edu/berkeley/cs/chisel3_2.11/3.1.0/chisel3_2.11-3.1.0.jar.sha1
// Downloaded https://repo1.maven.org/maven2/edu/berkeley/cs/chisel3_2.11/3.1.0/chisel3_2.11-3.1.0.jar.sha1
// Downloading https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.11.12/scala-library-2.11.12.jar.sha1
// https://repo1.maven.org/maven2/com/ibm/icu/icu4j/58.2/icu4j-58… (70.63 %, 82411…
// https://repo1.maven.org/maven2/org/antlr/antlr4/4.7/antlr4-4.7… (67.29 %, 80227…
// https://repo1.maven.org/maven2/edu/berkeley/cs/firrtl_2.11/1.1… (28.48 %, 90058…
// https://repo1.maven.org/maven2/org/json4s/json4s-core_2.11/3.5… (21.29 %, 14691…
// https://repo1.maven.org/maven2/edu/berkeley/cs/chisel3_2.11/3.… (10.91 %, 16330…
//
// Downloaded https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.11.12/scala-library-2.11.12.jar.sha1
// Downloading https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.11.12/scala-library-2.11.12.jar
// https://repo1.maven.org/maven2/org/antlr/antlr4/4.7/antlr4-4.7… (74.16 %, 88419…
// https://repo1.maven.org/maven2/com/ibm/icu/icu4j/58.2/icu4j-58… (74.00 %, 86343…
// https://repo1.maven.org/maven2/org/json4s/json4s-core_2.11/3.5… (35.54 %, 24522…
// https://repo1.maven.org/maven2/edu/berkeley/cs/firrtl_2.11/1.1… (31.59 %, 99888…
// https://repo1.maven.org/maven2/edu/berkeley/cs/chisel3_2.11/3.… (25.14 %, 37629…
//
// https://repo1.maven.org/maven2/org/antlr/antlr4/4.7/antlr4-4.7… (81.03 %, 96611…
// https://repo1.maven.org/maven2/com/ibm/icu/icu4j/58.2/icu4j-58… (75.55 %, 88145…
// https://repo1.maven.org/maven2/org/json4s/json4s-core_2.11/3.5… (49.79 %, 34352…
// https://repo1.maven.org/maven2/edu/berkeley/cs/chisel3_2.11/3.… (38.27 %, 57290…
// https://repo1.maven.org/maven2/edu/berkeley/cs/firrtl_2.11/1.1… (35.22 %, 11135…
// https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.… (8.83 %, 507904…
//
// https://repo1.maven.org/maven2/org/antlr/antlr4/4.7/antlr4-4.7… (86.53 %, 10316…
// https://repo1.maven.org/maven2/com/ibm/icu/icu4j/58.2/icu4j-58… (77.51 %, 90439…
// https://repo1.maven.org/maven2/org/json4s/json4s-core_2.11/3.5… (61.66 %, 42544…
// https://repo1.maven.org/maven2/edu/berkeley/cs/chisel3_2.11/3.… (49.22 %, 73674…
// https://repo1.maven.org/maven2/edu/berkeley/cs/firrtl_2.11/1.1… (38.84 %, 12282…
// https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.… (13.39 %, 77004…
//
// https://repo1.maven.org/maven2/org/antlr/antlr4/4.7/antlr4-4.7… (90.65 %, 10808…
// https://repo1.maven.org/maven2/com/ibm/icu/icu4j/58.2/icu4j-58… (79.20 %, 92405…
// https://repo1.maven.org/maven2/org/json4s/json4s-core_2.11/3.5… (73.53 %, 50736…
// https://repo1.maven.org/maven2/edu/berkeley/cs/chisel3_2.11/3.… (60.17 %, 90058…
// https://repo1.maven.org/maven2/edu/berkeley/cs/firrtl_2.11/1.1… (41.44 %, 13101…
// https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.… (17.38 %, 99942…
// https://repo1.maven.org/maven2/org/antlr/antlr4/4.7/antlr4-4.7… (96.15 %, 11463…
// https://repo1.maven.org/maven2/org/json4s/json4s-core_2.11/3.5… (87.78 %, 60567…
// https://repo1.maven.org/maven2/com/ibm/icu/icu4j/58.2/icu4j-58… (80.74 %, 94208…
// https://repo1.maven.org/maven2/edu/berkeley/cs/chisel3_2.11/3.… (67.83 %, 10152…
// https://repo1.maven.org/maven2/edu/berkeley/cs/firrtl_2.11/1.1… (45.06 %, 14248…
// https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.… (21.09 %, 12124…
//
// Downloaded https://repo1.maven.org/maven2/org/json4s/json4s-core_2.11/3.5.3/json4s-core_2.11-3.5.3.jar
// Downloading https://repo1.maven.org/maven2/com/thoughtworks/paranamer/paranamer/2.8/paranamer-2.8.jar.sha1
// Downloaded https://repo1.maven.org/maven2/org/antlr/antlr4/4.7/antlr4-4.7.jar
// Downloading https://repo1.maven.org/maven2/com/thoughtworks/paranamer/paranamer/2.8/paranamer-2.8.jar
// Downloaded https://repo1.maven.org/maven2/com/thoughtworks/paranamer/paranamer/2.8/paranamer-2.8.jar.sha1
// Downloading https://repo1.maven.org/maven2/joda-time/joda-time/2.9.4/joda-time-2.9.4.jar
// https://repo1.maven.org/maven2/com/ibm/icu/icu4j/58.2/icu4j-58… (82.57 %, 96337…
// https://repo1.maven.org/maven2/edu/berkeley/cs/chisel3_2.11/3.… (76.58 %, 11463…
// https://repo1.maven.org/maven2/edu/berkeley/cs/firrtl_2.11/1.1… (49.21 %, 15559…
// https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.… (24.79 %, 14254…
//
// Downloaded https://repo1.maven.org/maven2/com/thoughtworks/paranamer/paranamer/2.8/paranamer-2.8.jar
// Downloading https://repo1.maven.org/maven2/joda-time/joda-time/2.9.4/joda-time-2.9.4.jar.sha1
// https://repo1.maven.org/maven2/com/ibm/icu/icu4j/58.2/icu4j-58… (84.25 %, 98304…
// https://repo1.maven.org/maven2/edu/berkeley/cs/chisel3_2.11/3.… (82.06 %, 12282…
// https://repo1.maven.org/maven2/edu/berkeley/cs/firrtl_2.11/1.1… (52.32 %, 16542…
// https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.… (28.26 %, 16247…
// https://repo1.maven.org/maven2/joda-time/joda-time/2.9.4/joda-… (15.53 %, 97764…
//
// Downloaded https://repo1.maven.org/maven2/joda-time/joda-time/2.9.4/joda-time-2.9.4.jar.sha1
// https://repo1.maven.org/maven2/edu/berkeley/cs/chisel3_2.11/3.… (89.72 %, 13429…
// https://repo1.maven.org/maven2/com/ibm/icu/icu4j/58.2/icu4j-58… (86.64 %, 10108…
// https://repo1.maven.org/maven2/edu/berkeley/cs/firrtl_2.11/1.1… (55.94 %, 17689…
// https://repo1.maven.org/maven2/joda-time/joda-time/2.9.4/joda-… (46.76 %, 29437…
// https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.… (31.92 %, 18350…
//
// https://repo1.maven.org/maven2/edu/berkeley/cs/chisel3_2.11/3.… (96.29 %, 14412…
// https://repo1.maven.org/maven2/com/ibm/icu/icu4j/58.2/icu4j-58… (88.89 %, 10371…
// https://repo1.maven.org/maven2/joda-time/joda-time/2.9.4/joda-… (75.39 %, 47459…
// https://repo1.maven.org/maven2/edu/berkeley/cs/firrtl_2.11/1.1… (59.05 %, 18672…
// https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.… (35.34 %, 20316…
//
// Downloaded https://repo1.maven.org/maven2/edu/berkeley/cs/chisel3_2.11/3.1.0/chisel3_2.11-3.1.0.jar
// Downloaded https://repo1.maven.org/maven2/joda-time/joda-time/2.9.4/joda-time-2.9.4.jar
// https://repo1.maven.org/maven2/com/ibm/icu/icu4j/58.2/icu4j-58… (91.13 %, 10633…
// https://repo1.maven.org/maven2/edu/berkeley/cs/firrtl_2.11/1.1… (61.12 %, 19327…
// https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.… (38.19 %, 21954…
//
// https://repo1.maven.org/maven2/com/ibm/icu/icu4j/58.2/icu4j-58… (93.38 %, 10895…
// https://repo1.maven.org/maven2/edu/berkeley/cs/firrtl_2.11/1.1… (63.72 %, 20146…
// https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.… (40.47 %, 23265…
//
// https://repo1.maven.org/maven2/com/ibm/icu/icu4j/58.2/icu4j-58… (95.06 %, 11091…
// https://repo1.maven.org/maven2/edu/berkeley/cs/firrtl_2.11/1.1… (65.27 %, 20638…
// https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.… (42.18 %, 24248…
//
// https://repo1.maven.org/maven2/com/ibm/icu/icu4j/58.2/icu4j-58… (96.33 %, 11239…
// https://repo1.maven.org/maven2/edu/berkeley/cs/firrtl_2.11/1.1… (66.82 %, 21129…
// https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.… (43.60 %, 25067…
//
// https://repo1.maven.org/maven2/com/ibm/icu/icu4j/58.2/icu4j-58… (97.03 %, 11321…
// https://repo1.maven.org/maven2/edu/berkeley/cs/firrtl_2.11/1.1… (68.90 %, 21785…
// https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.… (45.59 %, 26214…
//
// https://repo1.maven.org/maven2/com/ibm/icu/icu4j/58.2/icu4j-58… (97.87 %, 11419…
// https://repo1.maven.org/maven2/edu/berkeley/cs/firrtl_2.11/1.1… (70.97 %, 22440…
// https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.… (47.30 %, 27197…
//
// https://repo1.maven.org/maven2/com/ibm/icu/icu4j/58.2/icu4j-58… (98.72 %, 11517…
// https://repo1.maven.org/maven2/edu/berkeley/cs/firrtl_2.11/1.1… (73.56 %, 23259…
// https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.… (48.73 %, 28016…
//
// https://repo1.maven.org/maven2/com/ibm/icu/icu4j/58.2/icu4j-58… (99.56 %, 11616…
// https://repo1.maven.org/maven2/edu/berkeley/cs/firrtl_2.11/1.1… (76.67 %, 24242…
// https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.… (50.63 %, 29110…
//
// Downloaded https://repo1.maven.org/maven2/com/ibm/icu/icu4j/58.2/icu4j-58.2.jar
// https://repo1.maven.org/maven2/edu/berkeley/cs/firrtl_2.11/1.1… (79.78 %, 25225…
// https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.… (52.43 %, 30146…
//
// https://repo1.maven.org/maven2/edu/berkeley/cs/firrtl_2.11/1.1… (84.96 %, 26864…
// https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.… (54.43 %, 31293…
//
// https://repo1.maven.org/maven2/edu/berkeley/cs/firrtl_2.11/1.1… (90.66 %, 28666…
// https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.… (56.71 %, 32604…
//
// https://repo1.maven.org/maven2/edu/berkeley/cs/firrtl_2.11/1.1… (95.32 %, 30141…
// https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.… (58.99 %, 33914…
//
// https://repo1.maven.org/maven2/edu/berkeley/cs/firrtl_2.11/1.1… (100.00 %, 3162…
// https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.… (61.27 %, 35225…
//
// Downloaded https://repo1.maven.org/maven2/edu/berkeley/cs/firrtl_2.11/1.1.0/firrtl_2.11-1.1.0.jar
// https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.… (64.17 %, 36891…
//
// https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.… (66.68 %, 38338…
//
// https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.… (68.11 %, 39157…
//
// https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.… (69.82 %, 40140…
//
// https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.… (71.81 %, 41287…
//
// https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.… (73.52 %, 42270…
//
// https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.… (74.95 %, 43089…
//
// https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.… (77.56 %, 44592…
//
// https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.… (79.51 %, 45711…
//
// https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.… (81.98 %, 47132…
//
// https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.… (84.35 %, 48496…
//
// https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.… (87.20 %, 50135…
//
// https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.… (90.33 %, 51937…
//
// https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.… (93.47 %, 53739…
//
// https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.… (96.03 %, 55214…
//
// https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.… (99.17 %, 57016…
//
// Downloaded https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.11.12/scala-library-2.11.12.jar
// Downloading https://repo1.maven.org/maven2/edu/berkeley/cs/chisel-iotesters_2.11/1.2.0/chisel-iotesters_2.11-1.2.0.pom
// Downloading https://repo1.maven.org/maven2/edu/berkeley/cs/chisel-iotesters_2.11/1.2.0/chisel-iotesters_2.11-1.2.0.pom.sha1
// Downloaded https://repo1.maven.org/maven2/edu/berkeley/cs/chisel-iotesters_2.11/1.2.0/chisel-iotesters_2.11-1.2.0.pom.sha1
// Downloaded https://repo1.maven.org/maven2/edu/berkeley/cs/chisel-iotesters_2.11/1.2.0/chisel-iotesters_2.11-1.2.0.pom
// Downloading https://repo1.maven.org/maven2/edu/berkeley/cs/chisel-iotesters_2.11/1.2.0/
// Downloaded https://repo1.maven.org/maven2/edu/berkeley/cs/chisel-iotesters_2.11/1.2.0/
// Downloading https://repo1.maven.org/maven2/org/scalacheck/scalacheck_2.11/1.13.4/scalacheck_2.11-1.13.4.pom
// Downloading https://repo1.maven.org/maven2/org/scalacheck/scalacheck_2.11/1.13.4/scalacheck_2.11-1.13.4.pom.sha1
// Downloading https://repo1.maven.org/maven2/org/scalatest/scalatest_2.11/3.0.1/scalatest_2.11-3.0.1.pom.sha1
// Downloading https://repo1.maven.org/maven2/org/scalatest/scalatest_2.11/3.0.1/scalatest_2.11-3.0.1.pom
// Downloading https://repo1.maven.org/maven2/edu/berkeley/cs/firrtl-interpreter_2.11/1.1.0/firrtl-interpreter_2.11-1.1.0.pom.sha1
// Downloading https://repo1.maven.org/maven2/edu/berkeley/cs/firrtl-interpreter_2.11/1.1.0/firrtl-interpreter_2.11-1.1.0.pom
// Downloaded https://repo1.maven.org/maven2/org/scalacheck/scalacheck_2.11/1.13.4/scalacheck_2.11-1.13.4.pom.sha1
// Downloaded https://repo1.maven.org/maven2/org/scalacheck/scalacheck_2.11/1.13.4/scalacheck_2.11-1.13.4.pom
// Downloading https://repo1.maven.org/maven2/org/scalacheck/scalacheck_2.11/1.13.4/
// Downloaded https://repo1.maven.org/maven2/org/scalacheck/scalacheck_2.11/1.13.4/
// Downloaded https://repo1.maven.org/maven2/org/scalatest/scalatest_2.11/3.0.1/scalatest_2.11-3.0.1.pom.sha1
// Downloaded https://repo1.maven.org/maven2/org/scalatest/scalatest_2.11/3.0.1/scalatest_2.11-3.0.1.pom
// Downloaded https://repo1.maven.org/maven2/edu/berkeley/cs/firrtl-interpreter_2.11/1.1.0/firrtl-interpreter_2.11-1.1.0.pom
// Downloaded https://repo1.maven.org/maven2/edu/berkeley/cs/firrtl-interpreter_2.11/1.1.0/firrtl-interpreter_2.11-1.1.0.pom.sha1
// Downloading https://repo1.maven.org/maven2/org/scalatest/scalatest_2.11/3.0.1/
// Downloading https://repo1.maven.org/maven2/edu/berkeley/cs/firrtl-interpreter_2.11/1.1.0/
// Downloaded https://repo1.maven.org/maven2/edu/berkeley/cs/firrtl-interpreter_2.11/1.1.0/
// Downloaded https://repo1.maven.org/maven2/org/scalatest/scalatest_2.11/3.0.1/
// Downloading https://repo1.maven.org/maven2/org/scalactic/scalactic_2.11/3.0.1/scalactic_2.11-3.0.1.pom
// Downloading https://repo1.maven.org/maven2/org/scalactic/scalactic_2.11/3.0.1/scalactic_2.11-3.0.1.pom.sha1
// Downloading https://repo1.maven.org/maven2/org/scala-sbt/test-interface/1.0/test-interface-1.0.pom
// Downloading https://repo1.maven.org/maven2/org/scala-sbt/test-interface/1.0/test-interface-1.0.pom.sha1
// Downloading https://repo1.maven.org/maven2/org/scala-lang/modules/scala-jline/2.12.1/scala-jline-2.12.1.pom
// Downloading https://repo1.maven.org/maven2/org/scala-lang/modules/scala-jline/2.12.1/scala-jline-2.12.1.pom.sha1
// Downloaded https://repo1.maven.org/maven2/org/scalactic/scalactic_2.11/3.0.1/scalactic_2.11-3.0.1.pom.sha1
// Downloaded https://repo1.maven.org/maven2/org/scalactic/scalactic_2.11/3.0.1/scalactic_2.11-3.0.1.pom
// Downloading https://repo1.maven.org/maven2/org/scalactic/scalactic_2.11/3.0.1/
// Downloaded https://repo1.maven.org/maven2/org/scala-lang/modules/scala-jline/2.12.1/scala-jline-2.12.1.pom
// Downloaded https://repo1.maven.org/maven2/org/scala-sbt/test-interface/1.0/test-interface-1.0.pom.sha1
// Downloaded https://repo1.maven.org/maven2/org/scala-sbt/test-interface/1.0/test-interface-1.0.pom
// Downloading https://repo1.maven.org/maven2/org/scala-sbt/test-interface/1.0/
// Downloaded https://repo1.maven.org/maven2/org/scalactic/scalactic_2.11/3.0.1/
// Downloaded https://repo1.maven.org/maven2/org/scala-sbt/test-interface/1.0/
// Downloaded https://repo1.maven.org/maven2/org/scala-lang/modules/scala-jline/2.12.1/scala-jline-2.12.1.pom.sha1
// Downloading https://repo1.maven.org/maven2/org/scala-lang/modules/scala-jline/2.12.1/
// Downloaded https://repo1.maven.org/maven2/org/scala-lang/modules/scala-jline/2.12.1/
// Downloading https://repo1.maven.org/maven2/org/fusesource/jansi/jansi/1.11/jansi-1.11.pom.sha1
// Downloading https://repo1.maven.org/maven2/org/fusesource/jansi/jansi/1.11/jansi-1.11.pom
// Downloaded https://repo1.maven.org/maven2/org/fusesource/jansi/jansi/1.11/jansi-1.11.pom.sha1
// Downloaded https://repo1.maven.org/maven2/org/fusesource/jansi/jansi/1.11/jansi-1.11.pom
// Downloading https://repo1.maven.org/maven2/org/fusesource/jansi/jansi/1.11/
// Downloaded https://repo1.maven.org/maven2/org/fusesource/jansi/jansi/1.11/
// Downloading https://repo1.maven.org/maven2/org/fusesource/jansi/jansi-project/1.11/jansi-project-1.11.pom
// Downloading https://repo1.maven.org/maven2/org/fusesource/jansi/jansi-project/1.11/jansi-project-1.11.pom.sha1
// Downloaded https://repo1.maven.org/maven2/org/fusesource/jansi/jansi-project/1.11/jansi-project-1.11.pom
// Downloaded https://repo1.maven.org/maven2/org/fusesource/jansi/jansi-project/1.11/jansi-project-1.11.pom.sha1
// Downloading https://repo1.maven.org/maven2/org/fusesource/jansi/jansi-project/1.11/
// Downloaded https://repo1.maven.org/maven2/org/fusesource/jansi/jansi-project/1.11/
// Downloading https://repo1.maven.org/maven2/org/fusesource/fusesource-pom/1.8/fusesource-pom-1.8.pom
// Downloading https://repo1.maven.org/maven2/org/fusesource/fusesource-pom/1.8/fusesource-pom-1.8.pom.sha1
// Downloaded https://repo1.maven.org/maven2/org/fusesource/fusesource-pom/1.8/fusesource-pom-1.8.pom.sha1
// Downloaded https://repo1.maven.org/maven2/org/fusesource/fusesource-pom/1.8/fusesource-pom-1.8.pom
// Downloading https://repo1.maven.org/maven2/org/fusesource/fusesource-pom/1.8/
// Downloaded https://repo1.maven.org/maven2/org/fusesource/fusesource-pom/1.8/
// Downloading https://repo1.maven.org/maven2/org/scalactic/scalactic_2.11/3.0.1/scalactic_2.11-3.0.1.jar
// Downloading https://repo1.maven.org/maven2/org/scalactic/scalactic_2.11/3.0.1/scalactic_2.11-3.0.1.jar.sha1
// Downloading https://repo1.maven.org/maven2/edu/berkeley/cs/firrtl-interpreter_2.11/1.1.0/firrtl-interpreter_2.11-1.1.0.jar
// Downloading https://repo1.maven.org/maven2/edu/berkeley/cs/firrtl-interpreter_2.11/1.1.0/firrtl-interpreter_2.11-1.1.0.jar.sha1
// Downloading https://repo1.maven.org/maven2/org/fusesource/jansi/jansi/1.11/jansi-1.11.jar
// Downloading https://repo1.maven.org/maven2/org/fusesource/jansi/jansi/1.11/jansi-1.11.jar.sha1
// Downloaded https://repo1.maven.org/maven2/org/scalactic/scalactic_2.11/3.0.1/scalactic_2.11-3.0.1.jar.sha1
// Downloading https://repo1.maven.org/maven2/org/scalatest/scalatest_2.11/3.0.1/scalatest_2.11-3.0.1.jar
// Downloaded https://repo1.maven.org/maven2/edu/berkeley/cs/firrtl-interpreter_2.11/1.1.0/firrtl-interpreter_2.11-1.1.0.jar.sha1
// ...
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (45.36 %, 45917…
//
// https://repo1.maven.org/maven2/org/typelevel/spire_2.11/0.14.1… (63.14 %, 53734…
// https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.13.2… (56.37 %, 85191…
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (45.85 %, 46408…
// https://repo1.maven.org/maven2/org/typelevel/spire_2.11/0.14.1… (64.27 %, 54691…
// https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.13.2… (57.13 %, 86338…
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (46.50 %, 47064…
//
// https://repo1.maven.org/maven2/org/typelevel/spire_2.11/0.14.1… (65.07 %, 55372…
// https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.13.2… (57.89 %, 87484…
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (47.25 %, 47830…
//
// https://repo1.maven.org/maven2/org/typelevel/spire_2.11/0.14.1… (65.84 %, 56027…
// https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.13.2… (58.54 %, 88467…
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (48.06 %, 48649…
//
// https://repo1.maven.org/maven2/org/typelevel/spire_2.11/0.14.1… (66.61 %, 56683…
// https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.13.2… (59.19 %, 89451…
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (48.93 %, 49521…
//
// https://repo1.maven.org/maven2/org/typelevel/spire_2.11/0.14.1… (67.57 %, 57502…
// https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.13.2… (59.84 %, 90434…
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (49.74 %, 50341…
//
// https://repo1.maven.org/maven2/org/typelevel/spire_2.11/0.14.1… (68.66 %, 58431…
// https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.13.2… (60.49 %, 91417…
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (50.71 %, 51324…
//
// https://repo1.maven.org/maven2/org/typelevel/spire_2.11/0.14.1… (69.50 %, 59140…
// https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.13.2… (61.25 %, 92563…
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (51.60 %, 52226…
//
// https://repo1.maven.org/maven2/org/typelevel/spire_2.11/0.14.1… (70.20 %, 59742…
// https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.13.2… (61.79 %, 93383…
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (52.00 %, 52634…
//
// https://repo1.maven.org/maven2/org/typelevel/spire_2.11/0.14.1… (71.04 %, 60451…
// https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.13.2… (62.67 %, 94721…
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (52.65 %, 53290…
//
// https://repo1.maven.org/maven2/org/typelevel/spire_2.11/0.14.1… (71.81 %, 61106…
// https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.13.2… (63.20 %, 95513…
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (53.30 %, 53945…
//
// https://repo1.maven.org/maven2/org/typelevel/spire_2.11/0.14.1… (72.77 %, 61926…
// https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.13.2… (64.06 %, 96823…
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (53.94 %, 54600…
//
// https://repo1.maven.org/maven2/org/typelevel/spire_2.11/0.14.1… (73.73 %, 62745…
// https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.13.2… (64.82 %, 97970…
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (54.81 %, 55475…
//
// https://repo1.maven.org/maven2/org/typelevel/spire_2.11/0.14.1… (74.82 %, 63674…
// https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.13.2… (65.47 %, 98953…
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (55.40 %, 56075…
//
// https://repo1.maven.org/maven2/org/typelevel/spire_2.11/0.14.1… (75.85 %, 64547…
// https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.13.2… (66.40 %, 10034…
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (56.37 %, 57058…
//
// https://repo1.maven.org/maven2/org/typelevel/spire_2.11/0.14.1… (76.81 %, 65366…
// https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.13.2… (67.21 %, 10157…
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (57.18 %, 57877…
//
// https://repo1.maven.org/maven2/org/typelevel/spire_2.11/0.14.1… (78.16 %, 66513…
// https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.13.2… (67.86 %, 10255…
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (57.99 %, 58696…
//
// https://repo1.maven.org/maven2/org/typelevel/spire_2.11/0.14.1… (79.31 %, 67496…
// https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.13.2… (68.62 %, 10370…
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (58.80 %, 59516…
//
// https://repo1.maven.org/maven2/org/typelevel/spire_2.11/0.14.1… (80.28 %, 68315…
// https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.13.2… (69.27 %, 10468…
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (59.39 %, 60118…
//
// https://repo1.maven.org/maven2/org/typelevel/spire_2.11/0.14.1… (81.43 %, 69298…
// https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.13.2… (70.03 %, 10583…
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (59.77 %, 60499…
//
// https://repo1.maven.org/maven2/org/typelevel/spire_2.11/0.14.1… (82.04 %, 69818…
// https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.13.2… (70.68 %, 10681…
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (60.26 %, 60990…
//
// https://repo1.maven.org/maven2/org/typelevel/spire_2.11/0.14.1… (82.78 %, 70445…
// https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.13.2… (71.22 %, 10763…
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (60.74 %, 61482…
//
// https://repo1.maven.org/maven2/org/typelevel/spire_2.11/0.14.1… (83.65 %, 71183…
// https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.13.2… (71.87 %, 10862…
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (61.07 %, 61809…
//
// https://repo1.maven.org/maven2/org/typelevel/spire_2.11/0.14.1… (84.32 %, 71756…
// https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.13.2… (72.52 %, 10960…
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (61.39 %, 62137…
//
// https://repo1.maven.org/maven2/org/typelevel/spire_2.11/0.14.1… (85.28 %, 72575…
// https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.13.2… (72.95 %, 11025…
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (61.88 %, 62629…
//
// https://repo1.maven.org/maven2/org/typelevel/spire_2.11/0.14.1… (86.44 %, 73558…
// https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.13.2… (73.17 %, 11058…
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (62.20 %, 62956…
//
// https://repo1.maven.org/maven2/org/typelevel/spire_2.11/0.14.1… (88.14 %, 75007…
// https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.13.2… (73.50 %, 11107…
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (62.63 %, 63394…
//
// https://repo1.maven.org/maven2/org/typelevel/spire_2.11/0.14.1… (89.71 %, 76344…
// https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.13.2… (73.71 %, 11140…
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (62.85 %, 63612…
//
// https://repo1.maven.org/maven2/org/typelevel/spire_2.11/0.14.1… (91.06 %, 77490…
// https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.13.2… (74.15 %, 11206…
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (63.33 %, 64103…
//
// https://repo1.maven.org/maven2/org/typelevel/spire_2.11/0.14.1… (92.02 %, 78310…
// https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.13.2… (74.47 %, 11255…
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (63.68 %, 64458…
//
// https://repo1.maven.org/maven2/org/typelevel/spire_2.11/0.14.1… (92.98 %, 79129…
// https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.13.2… (74.91 %, 11320…
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (63.98 %, 64759…
//
// https://repo1.maven.org/maven2/org/typelevel/spire_2.11/0.14.1… (93.75 %, 79784…
// https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.13.2… (75.36 %, 11389…
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (64.52 %, 65305…
//
// https://repo1.maven.org/maven2/org/typelevel/spire_2.11/0.14.1… (94.36 %, 80303…
// https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.13.2… (75.88 %, 11468…
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (64.79 %, 65578…
//
// https://repo1.maven.org/maven2/org/typelevel/spire_2.11/0.14.1… (94.91 %, 80767…
// https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.13.2… (76.21 %, 11517…
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (65.46 %, 66261…
//
// https://repo1.maven.org/maven2/org/typelevel/spire_2.11/0.14.1… (95.29 %, 81095…
// https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.13.2… (76.75 %, 11599…
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (65.92 %, 66725…
// https://repo1.maven.org/maven2/org/typelevel/spire_2.11/0.14.1… (96.00 %, 81697…
// https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.13.2… (77.29 %, 11681…
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (66.41 %, 67216…
//
// https://repo1.maven.org/maven2/org/typelevel/spire_2.11/0.14.1… (96.45 %, 82078…
// https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.13.2… (77.87 %, 11768…
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (66.92 %, 67735…
//
// https://repo1.maven.org/maven2/org/typelevel/spire_2.11/0.14.1… (96.84 %, 82406…
// https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.13.2… (78.48 %, 11861…
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (67.38 %, 68199…
//
// https://repo1.maven.org/maven2/org/typelevel/spire_2.11/0.14.1… (97.41 %, 82897…
// https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.13.2… (79.24 %, 11976…
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (67.86 %, 68691…
//
// https://repo1.maven.org/maven2/org/typelevel/spire_2.11/0.14.1… (97.99 %, 83389…
// https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.13.2… (80.45 %, 12159…
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (68.51 %, 69346…
//
// https://repo1.maven.org/maven2/org/typelevel/spire_2.11/0.14.1… (98.57 %, 83880…
// https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.13.2… (81.72 %, 12350…
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (69.38 %, 70220…
//
// https://repo1.maven.org/maven2/org/typelevel/spire_2.11/0.14.1… (99.53 %, 84699…
// https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.13.2… (82.39 %, 12451…
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (70.45 %, 71312…
//
// Downloaded https://repo1.maven.org/maven2/org/typelevel/spire_2.11/0.14.1/spire_2.11-0.14.1.jar
// https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.13.2… (83.14 %, 12565…
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (71.43 %, 72295…
//
// https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.13.2… (83.90 %, 12680…
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (72.40 %, 73278…
//
// https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.13.2… (84.45 %, 12762…
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (73.53 %, 74425…
//
// https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.13.2… (85.20 %, 12877…
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (74.50 %, 75408…
//
// https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.13.2… (85.85 %, 12975…
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (75.47 %, 76391…
//
// https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.13.2… (86.51 %, 13073…
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (76.60 %, 77538…
//
// https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.13.2… (86.94 %, 13139…
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (77.41 %, 78357…
//
// https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.13.2… (87.37 %, 13204…
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (78.55 %, 79504…
//
// https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.13.2… (87.81 %, 13270…
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (79.68 %, 80651…
//
// https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.13.2… (88.24 %, 13336…
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (80.81 %, 81798…
//
// https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.13.2… (88.67 %, 13401…
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (81.78 %, 82781…
//
// https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.13.2… (89.23 %, 13486…
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (82.62 %, 83628…
//
// https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.13.2… (89.76 %, 13565…
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (83.40 %, 84419…
//
// https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.13.2… (90.30 %, 13647…
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (84.05 %, 85075…
//
// https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.13.2… (90.84 %, 13729…
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (84.70 %, 85730…
//
// https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.13.2… (91.28 %, 13794…
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (85.35 %, 86385…
//
// https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.13.2… (91.75 %, 13865…
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (86.16 %, 87205…
//
// https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.13.2… (92.25 %, 13942…
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (86.96 %, 88024…
//
// https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.13.2… (92.68 %, 14007…
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (87.61 %, 88679…
//
// https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.13.2… (93.33 %, 14106…
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (88.42 %, 89498…
//
// https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.13.2… (93.66 %, 14155…
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (89.07 %, 90154…
//
// https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.13.2… (94.20 %, 14237…
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (89.88 %, 90973…
//
// https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.13.2… (94.74 %, 14319…
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (90.69 %, 91792…
//
// https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.13.2… (95.29 %, 14400…
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (91.50 %, 92611…
//
// https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.13.2… (95.94 %, 14499…
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (92.36 %, 93486…
//
// https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.13.2… (96.70 %, 14613…
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (93.28 %, 94414…
//
// https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.13.2… (97.56 %, 14745…
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (94.09 %, 95233…
//
// https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.13.2… (98.32 %, 14859…
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (94.90 %, 96052…
//
// https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.13.2… (98.97 %, 14958…
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (96.11 %, 97282…
//
// https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.13.2… (99.44 %, 15029…
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (96.84 %, 98018…
//
// https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.13.2… (100.00 %, 1511…
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (97.81 %, 99001…
//
// Downloaded https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.13.2/breeze_2.11-0.13.2.jar
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (98.62 %, 99820…
//
// https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.… (99.38 %, 10058…
//
// Downloaded https://repo1.maven.org/maven2/org/spire-math/spire_2.11/0.13.0/spire_2.11-0.13.0.jar
// path: String = """
// C:\Users\pt27\source\repos\chisel-bootcamp/source/load-ivy.sc
// """

// %% [markdown]
// As mentioned in the last module, these statements are needed to import Chisel. **Run this cell now** before running any future code blocks.

// %%
import chisel3._
import chisel3.util._
import chisel3.iotesters.{ChiselFlatSpec, Driver, PeekPokeTester}
// Out:
// import chisel3._
//
// import chisel3.util._
//
// import chisel3.iotesters.{ChiselFlatSpec, Driver, PeekPokeTester}

// %% [markdown]
// ---
// # Your First Module
// This section will present your first hardware module, a test case, and how to run it. It will contain many things that you will not understand, and that is OK. We want you to take away the broad strokes, so you can continually return to this complete and working example to reinforce what you've learned.
//
// <span style="color:blue">**Example: A Module**</span><br>
// Like Verilog, we can declare module definitions in Chisel. The following example is a Chisel `Module`, `Passthrough`, that has one 4-bit input, `in`, and one 4-bit output, `out`. The module combinationally connects `in` and `out`, so `in` drives `out`.

// %%
// Chisel Code: Declare a new module definition
class Passthrough extends Module {
  val io = IO(new Bundle {
    val in = Input(UInt(4.W))
    val out = Output(UInt(4.W))
  })
  io.out := io.in
}
// Out:
// defined class Passthrough

// %% [markdown]
// There's a lot here! The following explains how to think of each line in terms of the hardware we are describing.
//
// ```scala
// class Passthrough extends Module {
// ```
// We declare a new module called `Passthrough`. `Module` is a built-in Chisel class that all hardware modules must extend.
//
// ```scala
// val io = IO(...)
// ```
// We declare all our input and output ports in a special `io` `val`. It must be called `io` and be an `IO` object or instance, which requires something of the form `IO(_instantiated_bundle_)`.
//
// ```scala
// new Bundle {
//     val in = Input(...)
//     val out = Output(...)
// }
// ```
// We declare a new hardware struct type (Bundle) that contains some named signals `in` and `out` with directions Input and Output, respectively.
//
// ```scala
// UInt(4.W)
// ```
// We declare a signal's hardware type. In this case, it is an unsigned integer of width 4.
//
// ```scala
// io.out := io.in
// ```
// We connect our input port to our output port, such that `io.in` *drives* `io.out`. Note that the `:=` operator is a ***Chisel*** operator that indicates that the right-hand signal drives the left-hand signal. It is a directioned operator.
//
// The neat thing about hardware construction languages (HCLs) is that we can use the underlying programming language as a scripting language. For example, after declaring our Chisel module, we then use Scala to call the Chisel compiler to translate Chisel `Passthrough` into Verilog `Passthrough`. This process is called ***elaboration***.

// %%
// Scala Code: Elaborate our Chisel design by translating it to Verilog
// Don't worry about understanding this code; it is very complicated Scala
println(getVerilog(new Passthrough))
// Out:
// [info] [0.000] Elaborating design...
// [info] [0.003] Done elaborating.
// Total FIRRTL Compile Time: 23.4 ms
// module cmd2WrapperHelperPassthrough( // @[:@3.2]
//   input        clock, // @[:@4.4]
//   input        reset, // @[:@5.4]
//   input  [3:0] io_in, // @[:@6.4]
//   output [3:0] io_out // @[:@6.4]
// );
//   assign io_out = io_in;
// endmodule

// %% [markdown]
// Note that the Name of our module is `cmd<#>WrapperHelperPassthrough`, which is an artifact of running this tutorial in Jupyter. In your normal code, its name should just be `Passthrough`. This is an important lesson though - although Chisel does its best to preserve the names of your modules and other hardware components, sometimes it fails to do so.
//
// <span style="color:blue">**Example: A Module Generator**</span><br>
// If we apply what we learned about Scala to this example, we can see that a Chisel module is implemented as a Scala class. Just like any other Scala class, we could make a Chisel module take some construction parameters. In this case, we make a new class `PassthroughGenerator` which will accept an integer `width` that dictates the widths of its input and output ports:

// %%
// Chisel Code, but pass in a parameter to set widths of ports
class PassthroughGenerator(width: Int) extends Module { 
  val io = IO(new Bundle {
    val in = Input(UInt(width.W))
    val out = Output(UInt(width.W))
  })
  io.out := io.in
}

// Let's now generate modules with different widths
println(getVerilog(new PassthroughGenerator(10)))
println(getVerilog(new PassthroughGenerator(20)))
// Out:
// [info] [0.000] Elaborating design...
// [info] [0.011] Done elaborating.
// Total FIRRTL Compile Time: 12.7 ms
// module cmd5WrapperHelperPassthroughGenerator( // @[:@3.2]
//   input        clock, // @[:@4.4]
//   input        reset, // @[:@5.4]
//   input  [9:0] io_in, // @[:@6.4]
//   output [9:0] io_out // @[:@6.4]
// );
//   assign io_out = io_in;
// endmodule
//
// [info] [0.000] Elaborating design...
// [info] [0.004] Done elaborating.
// Total FIRRTL Compile Time: 11.2 ms
// module cmd5WrapperHelperPassthroughGenerator( // @[:@3.2]
//   input         clock, // @[:@4.4]
//   input         reset, // @[:@5.4]
//   input  [19:0] io_in, // @[:@6.4]
//   output [19:0] io_out // @[:@6.4]
// );
//   assign io_out = io_in;
// endmodule
// defined class PassthroughGenerator

// %% [markdown]
// Notice that the generated Verilog uses different bitwidths for the input/output depending on the value assigned to the `width` parameter. Let's dig into how this works. Because Chisel Modules are normal Scala classes, we can use the power of Scala's class constructors to parameterize the elaboration of our design.
//
// You may notice that this parameterization is enabled by *Scala*, not *Chisel*; Chisel has no extra APIs for parameterization, but a designer can simply leverage Scala features to parameterize his/her designs.
//
// Because `PassthroughGenerator` no longer describes a single Module, but instead describes a family of modules parameterized by `width`, we refer to this `Passthrough` as a ***generator***.

// %% [markdown]
// ---
// # Testing Your Hardware
//
// No hardware module or generator should be complete without a tester. Chisel has built-in test features that you will explore throughout this bootcamp. The following example is a Chisel test harness that passes values to an instance of `Passthrough`'s input port `in`, and checks that the same value is seen on the output port `out`.
//
// <span style="color:blue">**Example: A Tester**</span><br>
// There is a ***LOT*** of crazy Scala going on here, so no need to understand anything except the `poke` and `expect` commands. You can think of the rest of the code as simply boilerplate to write these simple tests.

// %%
// Scala Code: Calling Driver to instantiate Passthrough + PeekPokeTester and execute the test.
// Don't worry about understanding this code; it is very complicated Scala.
// Think of it more as boilerplate to run a Chisel test.
val testResult = Driver(() => new Passthrough()){
    c => new PeekPokeTester(c) {
    poke(c.io.in, 0)     // Set our input to value 0
    expect(c.io.out, 0)  // Assert that the output correctly has 0
    poke(c.io.in, 1)     // Set our input to value 1
    expect(c.io.out, 1)  // Assert that the output correctly has 1
    poke(c.io.in, 2)     // Set our input to value 2
    expect(c.io.out, 2)  // Assert that the output correctly has 2
  }
}
assert(testResult)   // Scala Code: if testResult == false, will throw an error
println("SUCCESS!!") // Scala Code: if we get here, our tests passed!
// Out:
// [info] [0.000] Elaborating design...
// [info] [0.003] Done elaborating.
// Total FIRRTL Compile Time: 5.9 ms
// Total FIRRTL Compile Time: 8.8 ms
// End of dependency graph
// Circuit state created
// [info] [0.001] SEED 1543234510231
// test cmd2WrapperHelperPassthrough Success: 3 tests passed in 5 cycles taking 0.001845 seconds
// [info] [0.002] RAN 0 CYCLES PASSED
// SUCCESS!!
// testResult: Boolean = true

// %% [markdown]
// What's going on? The test accepts a `Passthrough` module, assigns values to the module's inputs, and checks its outputs. To set an input, we call `poke`. To check an output, we call `expect`. If we don't want to compare the output to an expected value (no assertion), we can `peek` the output instead.
//
// If all `expect` statements are true, then our boilerplate code will return true (see `testResult`).

// %% [markdown]
// <span style="color:red">**Exercise: Writing Your Own Testers**</span><br>
// Write and execute two tests, one that tests `PassthroughGenerator` for a width of 10 and a second that tests `PassthroughGenerator` for a width of 20. Check at least two values for each: zero and the maximum value supported by the specified width. Note that the triple question mark has a special meaning in Scala. You may see it frequently in these bootcamp exercises. Running code with the `???` will produce the `NotImplementedError`. Replace `???` with your testers.

// %%
val test10result = Driver(() => new PassthroughGenerator(10)){
    c => new PeekPokeTester(c){
        poke(c.io.in,"haa".U)
        expect(c.io.out,"haa".U)
    }
}

val test20result = Driver(() => new PassthroughGenerator(16)){
    c => new PeekPokeTester(c){
        poke(c.io.in,"haab1".U)
        expect(c.io.out,"haab1".U)
    }
}

assert((test10result == true) && (test20result == true))
println("SUCCESS!!") // Scala Code: if we get here, our tests passed!
// Out:
// [info] [0.000] Elaborating design...
// [info] [0.008] Done elaborating.
// Total FIRRTL Compile Time: 7.0 ms
// Total FIRRTL Compile Time: 6.6 ms
// End of dependency graph
// Circuit state created
// [info] [0.000] SEED 1543235352717
// test cmd5WrapperHelperPassthroughGenerator Success: 1 tests passed in 5 cycles taking 0.005380 seconds
// [info] [0.005] RAN 0 CYCLES PASSED
// [info] [0.000] Elaborating design...
// [info] [0.006] Done elaborating.
// Total FIRRTL Compile Time: 8.0 ms
// Total FIRRTL Compile Time: 5.0 ms
// End of dependency graph
// Circuit state created
// [info] [0.000] SEED 1543235352770
// test cmd5WrapperHelperPassthroughGenerator Success: 1 tests passed in 5 cycles taking 0.002709 seconds
// [info] [0.002] RAN 0 CYCLES PASSED
// SUCCESS!!
// test10result: Boolean = true
// test20result: Boolean = true

// %% [markdown]
// <div id="container"><section id="accordion"><div>
// <input type="checkbox" id="check-1" />
// <label for="check-1"><strong>Solution</strong> (click to toggle displaying it)</label>
// <article>
// <pre style="background-color:#f7f7f7">
// val test10result = Driver(() => new PassthroughGenerator(10)) {
//   c => new PeekPokeTester(c) {
//     poke(c.io.in, 0)
//     expect(c.io.out, 0)
//     poke(c.io.in, 1023)
//     expect(c.io.out, 1023)
//   }
// }
//
// val test20result = Driver(() => new PassthroughGenerator(20)) {
//   c => new PeekPokeTester(c) {
//     poke(c.io.in, 0)
//     expect(c.io.out, 0)
//     poke(c.io.in, 1048575)
//     expect(c.io.out, 1048575)
//   }
// }
//
// </pre></article></div></section></div>

// %% [markdown]
// ---
// # Looking at Generated Verilog/FIRRTL
//
// If you are having trouble understanding the generated hardware and are comfortable with reading structural Verilog and/or FIRRTL (Chisel's IR which is comparable to a synthesis-only subset of Verilog), then you can try looking at the generated Verilog to see the result of Chisel execution.
//
// Here is an example of generating the Verilog (which you've seen already) and the FIRRTL.

// %%
// Viewing the Verilog for debugging
println(getVerilog(new Passthrough))
// Out:
// [info] [0.000] Elaborating design...
// [info] [0.010] Done elaborating.
// Total FIRRTL Compile Time: 14.7 ms
// module cmd2WrapperHelperPassthrough( // @[:@3.2]
//   input        clock, // @[:@4.4]
//   input        reset, // @[:@5.4]
//   input  [3:0] io_in, // @[:@6.4]
//   output [3:0] io_out // @[:@6.4]
// );
//   assign io_out = io_in;
// endmodule

// %%
// Viewing the firrtl for debugging
println(getFirrtl(new Passthrough))
// Out:
// [info] [0.001] Elaborating design...
// [info] [0.005] Done elaborating.
// ;buildInfoPackage: chisel3, version: 3.1.0, scalaVersion: 2.11.12, sbtVersion: 1.1.1, builtAtString: 2018-04-17 19:22:56.455, builtAtMillis: 1523992976455
// circuit cmd2WrapperHelperPassthrough :
//   module cmd2WrapperHelperPassthrough :
//     input clock : Clock
//     input reset : UInt<1>
//     output io : {flip in : UInt<4>, out : UInt<4>}
//
//     io.out <= io.in @[cmd2.sc 6:10]

// %% [markdown]
// ---
// # You're done!
//
// [Return to the top.](#top)

// %% [markdown]
// ## <span style="color:red"> Appendix: A Note on "printf" Debugging</span>
// [Debugging with print statements](https://stackoverflow.com/a/189570) is not always the best way to debug, but is often an easy first step to see what's going on when something doesn't work the way you expect.
// Because Chisel generators are programs generating hardware, there are some extra subtleties about printing generator and circuit state.
// It is important to remember when your print statement executes and what is being printed.
// The three common scenarios where you might want to print have some important differences:
// * Chisel generator prints during circuit generation
// * Circuit prints during circuit simulation
// * Tester prints during testing
//
// `println` is a built-in Scala function that prints to the console. It **cannot** be used to print during circuit simulation because the generated circuit is FIRRTL or Verilog- not Scala.
//
// The following code block shows different styles of printing.

// %%
class PrintingModule extends Module {
    val io = IO(new Bundle {
        val in = Input(UInt(4.W))
        val out = Output(UInt(4.W))
    })
    io.out := io.in

    printf("Print during simulation: Input is %d\n", io.in)
    // chisel printf has its own string interpolator too
    printf(p"Print during simulation: IO is $io\n")

    println(s"Print during generation: Input is ${io.in}")
}

class PrintingModuleTester(c: PrintingModule) extends PeekPokeTester(c) {
    poke(c.io.in, 3)
    step(5) // circuit will print
    
    println(s"Print during testing: Input is ${peek(c.io.in)}")
}
chisel3.iotesters.Driver( () => new PrintingModule ) { c => new PrintingModuleTester(c) }
// Out:
// [info] [0.000] Elaborating design...
// Print during generation: Input is chisel3.core.UInt@e
// [info] [0.034] Done elaborating.
// Total FIRRTL Compile Time: 33.4 ms
// Total FIRRTL Compile Time: 14.8 ms
// End of dependency graph
// Circuit state created
// [info] [0.000] SEED 1543235595911
// Print during simulation: Input is 3
// Print during simulation: IO is Bundle(in -> 3, out -> 3)
// Print during simulation: Input is 3
// Print during simulation: IO is Bundle(in -> 3, out -> 3)
// Print during simulation: Input is 3
// Print during simulation: IO is Bundle(in -> 3, out -> 3)
// Print during simulation: Input is 3
// Print during simulation: IO is Bundle(in -> 3, out -> 3)
// Print during simulation: Input is 3
// Print during simulation: IO is Bundle(in -> 3, out -> 3)
// [info] [0.005] Print during testing: Input is 3
// test cmd18WrapperHelperPrintingModule Success: 0 tests passed in 10 cycles taking 0.011866 seconds
// [info] [0.005] RAN 5 CYCLES PASSED
// defined class PrintingModule
// defined class PrintingModuleTester
// res18_2: Boolean = true
